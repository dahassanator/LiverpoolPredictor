# %%
import pandas as pd

# %%
matches = pd.read_csv("liverpool_data.csv", index_col = 0)

# %%
matches.dtypes
# Out:
# Date              object
# Time              object
# Round             object
# Day               object
# Venue             object
# Result            object
# GF                 int64
# GA                 int64
# Opponent          object
# xG_x             float64
# xGA              float64
# Poss               int64
# Attendance         int64
# Captain           object
# Formation         object
# Opp Formation     object
# Referee           object
# Match Report      object
# Notes            float64
# Sh                 int64
# SoT                int64
# Dist             float64
# FK                 int64
# PK                 int64
# PKatt              int64
# xG_y             float64
# dtype: object

# %%
matches["Date"] = pd.to_datetime(matches["Date"]) # converts "Date" column values to datetime data type

# %%
matches["venue_code"] = matches["Venue"].astype("category").cat.codes # gives away or home a value of 0 or 1

# %%
matches["opp_code"] = matches["Opponent"].astype("category").cat.codes # gives each unique opponent a number

# %%
matches["hour"] = matches["Time"].str.replace(":.+", "", regex=True).astype("int") # allows us to convert the time to an int

# %%
matches["day_code"] = matches["Date"].astype("category").dt.dayofweek # gets day of week property from the date

# %%
matches["target"] = (matches["Result"] == "W").astype("int") # converts win or loss/draw to numerical value

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)
# n_estimators=50 - number of individual decision trees to train
# min_samples_split=10 - number of samples in a leaf of the decision tree before splitting node
# random_state=1 - same results when ran multiple times

# %%
train = matches[matches["Date"] < '2024-01-01'] # training our data with first half of the season

# %%
test = matches[matches["Date"] > '2024-01-01'] # testing on the last half of the season

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"]) # train random forest model with predictors (defined above) to try to predict the target (win or loss/draw)
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors]) # generate predictions

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds) # passing in the actual data, to compare with the predictions, gives an accuracy score

# %%
acc # yields 72% accuracy, meaning our model made the right prediction 72% of the time
# Out:
# 0.7222222222222222

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds)) 
# creating a new dataframe with the actual results and predictions so we can compare

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"]) # consolodating our new dataframe
# results yield that 
# the model predicted 2 loss/draws, and was wrong 0 times
# the model predicted 11 wins, and was wrong 5 times
# Out:
# prediction  0   1
# actual
# 0           2   5
# 1           0  11

# %%
from sklearn.metrics import precision_score

# %%
precision_score(test["target"], preds) # when we predicted a win, the team actually won 68.75% of the time
# Out:
# 0.6875

# %%
# allows model to predict score based on 3 games before it
def rolling_averages(matches, cols, new_cols):
    matches = matches.sort_values("Date") # sort matches by dates
    rolling_stats = matches[cols].rolling(3, closed='left').mean() # take columns and compute rolling averages for the columns not including current week
    matches[new_cols] = rolling_stats # set the new columns as the rolling averages
    matches = matches.dropna(subset=new_cols) # drops missing values from dataframe (specifically in case where 3 games haven't been played yet)
    return matches

# %%
cols = ["GF", "GA", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"] # the columns we want rolling averages for
new_cols = [f"{c}_rolling" for c in cols] # adding the word "rolling" to the end of the names for the column titles

# %%
matches = rolling_averages(matches, cols, new_cols)

# %%
matches
# Out:
#          Date   Time         Round  Day Venue Result  GF  GA         Opponent  \
# 3  2023-09-03  14:00   Matchweek 4  Sun  Home      W   3   0      Aston Villa
# 4  2023-09-16  12:30   Matchweek 5  Sat  Away      W   3   1           Wolves
# 5  2023-09-24  14:00   Matchweek 6  Sun  Home      W   3   1         West Ham
# 6  2023-09-30  17:30   Matchweek 7  Sat  Away      L   1   2        Tottenham
# 7  2023-10-08  14:00   Matchweek 8  Sun  Away      D   2   2         Brighton
# 8  2023-10-21  12:30   Matchweek 9  Sat  Home      W   2   0          Everton
# 9  2023-10-29  14:00  Matchweek 10  Sun  Home      W   3   0  Nott'ham Forest
# 10 2023-11-05  16:30  Matchweek 11  Sun  Away      D   1   1       Luton Town
# 11 2023-11-12  14:00  Matchweek 12  Sun  Home      W   3   0        Brentford
# 12 2023-11-25  12:30  Matchweek 13  Sat  Away      D   1   1  Manchester City
# 13 2023-12-03  14:00  Matchweek 14  Sun  Home      W   4   3           Fulham
# 14 2023-12-06  19:30  Matchweek 15  Wed  Away      W   2   0    Sheffield Utd
# 15 2023-12-09  12:30  Matchweek 16  Sat  Away      W   2   1   Crystal Palace
# 16 2023-12-17  16:30  Matchweek 17  Sun  Home      D   0   0   Manchester Utd
# 17 2023-12-23  17:30  Matchweek 18  Sat  Home      D   1   1          Arsenal
# 18 2023-12-26  17:30  Matchweek 19  Tue  Away      W   2   0          Burnley
# 19 2024-01-01  20:00  Matchweek 20  Mon  Home      W   4   2    Newcastle Utd
# 20 2024-01-21  16:30  Matchweek 21  Sun  Away      W   4   0      Bournemouth
# 21 2024-01-31  20:15  Matchweek 22  Wed  Home      W   4   1          Chelsea
# 22 2024-02-04  16:30  Matchweek 23  Sun  Away      L   1   3          Arsenal
# 23 2024-02-10  15:00  Matchweek 24  Sat  Home      W   3   1          Burnley
# 24 2024-02-17  12:30  Matchweek 25  Sat  Away      W   4   1        Brentford
# 25 2024-02-21  19:30  Matchweek 26  Wed  Home      W   4   1       Luton Town
# 26 2024-03-02  15:00  Matchweek 27  Sat  Away      W   1   0  Nott'ham Forest
# 27 2024-03-10  15:45  Matchweek 28  Sun  Home      D   1   1  Manchester City
# 28 2024-03-31  14:00  Matchweek 30  Sun  Home      W   2   1         Brighton
# 29 2024-04-04  19:30  Matchweek 31  Thu  Home      W   3   1    Sheffield Utd
# 30 2024-04-07  15:30  Matchweek 32  Sun  Away      D   2   2   Manchester Utd
# 31 2024-04-14  14:00  Matchweek 33  Sun  Home      L   0   1   Crystal Palace
# 32 2024-04-21  16:30  Matchweek 34  Sun  Away      W   3   1           Fulham
# 33 2024-04-24  20:00  Matchweek 29  Wed  Away      L   0   2          Everton
# 34 2024-04-27  12:30  Matchweek 35  Sat  Away      D   2   2         West Ham
# 35 2024-05-05  16:30  Matchweek 36  Sun  Home      W   4   2        Tottenham
# 36 2024-05-13  20:00  Matchweek 37  Mon  Away      D   3   3      Aston Villa
# 37 2024-05-19  16:00  Matchweek 38  Sun  Home      W   2   0           Wolves
#
#     xG_x  ...  day_code  target  GF_rolling GA_rolling Sh_rolling SoT_rolling  \
# 3    2.5  ...         6       1    2.000000   1.000000  15.666667    4.666667
# 4    2.5  ...         5       1    2.666667   0.666667  17.000000    5.666667
# 5    3.0  ...         6       1    2.666667   0.666667  14.000000    4.333333
# 6    1.3  ...         5       0    3.000000   0.666667  18.000000    5.000000
# 7    2.3  ...         6       0    2.333333   1.333333  16.333333    5.000000
# 8    2.2  ...         5       1    2.000000   1.666667  15.333333    4.333333
# 9    3.2  ...         6       1    1.666667   1.333333  16.666667    4.000000
# 10   2.6  ...         6       0    2.333333   0.666667  19.666667    5.333333
# 11   1.7  ...         6       1    2.000000   0.333333  23.333333    6.333333
# 12   0.6  ...         5       0    2.333333   0.333333  20.666667    8.000000
# 13   2.1  ...         6       1    1.666667   0.666667  16.333333    6.333333
# 14   1.7  ...         2       1    2.666667   1.333333  17.000000    8.333333
# 15   1.2  ...         5       1    2.333333   1.333333  16.333333    7.666667
# 16   2.3  ...         6       0    2.666667   1.333333  18.333333    7.333333
# 17   1.0  ...         5       0    1.333333   0.333333  21.000000    6.000000
# 18   1.8  ...         1       1    1.000000   0.666667  20.333333    4.333333
# 19   7.0  ...         0       1    1.000000   0.333333  22.000000    7.000000
# 20   1.5  ...         6       1    2.333333   1.000000  21.333333    8.333333
# 21   2.9  ...         2       1    3.333333   0.666667  21.666667    9.666667
# 22   0.4  ...         6       0    4.000000   1.000000  24.333333   10.666667
# 23   2.8  ...         5       1    3.000000   1.333333  17.000000    7.000000
# 24   2.8  ...         5       1    2.666667   1.666667  20.666667    8.000000
# 25   3.3  ...         2       1    2.666667   1.666667  16.666667    6.333333
# 26   2.0  ...         5       1    3.666667   1.000000  23.000000   10.333333
# 27   2.7  ...         6       0    3.000000   0.666667  22.000000    7.333333
# 28   2.8  ...         6       1    2.000000   0.666667  23.000000    6.333333
# 29   1.8  ...         3       1    1.333333   0.666667  23.333333    4.666667
# 30   3.6  ...         6       0    2.000000   1.000000  25.666667    7.333333
# 31   2.7  ...         6       0    2.333333   1.333333  28.666667    7.666667
# 32   1.0  ...         6       1    1.666667   1.333333  25.666667    6.666667
# 33   2.1  ...         2       0    1.666667   1.333333  20.666667    6.000000
# 34   1.7  ...         5       0    1.000000   1.333333  19.333333    6.333333
# 35   3.3  ...         6       1    1.666667   1.666667  21.666667    7.333333
# 36   1.7  ...         0       0    2.000000   2.000000  25.333333    9.000000
# 37   4.5  ...         6       1    3.000000   2.333333  22.333333    9.000000
#
#    Dist_rolling FK_rolling  PK_rolling  PKatt_rolling
# 3     17.266667   0.666667    0.000000       0.333333
# 4     16.233333   0.666667    0.000000       0.333333
# 5     15.900000   0.333333    0.000000       0.000000
# 6     16.600000   0.666667    0.333333       0.333333
# 7     16.666667   0.666667    0.333333       0.333333
# 8     17.666667   0.666667    0.666667       0.666667
# 9     18.700000   0.333333    0.666667       0.666667
# 10    20.233333   1.000000    0.666667       0.666667
# 11    19.800000   1.000000    0.333333       0.333333
# 12    18.666667   0.666667    0.000000       0.000000
# 13    17.466667   0.000000    0.000000       0.000000
# 14    17.933333   0.333333    0.000000       0.000000
# 15    17.066667   0.333333    0.000000       0.000000
# 16    17.566667   0.333333    0.000000       0.000000
# 17    17.166667   0.000000    0.000000       0.000000
# 18    18.400000   0.333333    0.000000       0.000000
# 19    18.400000   0.333333    0.000000       0.000000
# 20    17.900000   0.333333    0.333333       0.666667
# 21    17.600000   0.000000    0.333333       0.666667
# 22    18.433333   0.666667    0.333333       1.000000
# 23    19.600000   0.666667    0.000000       0.333333
# 24    18.333333   0.666667    0.000000       0.333333
# 25    17.000000   0.333333    0.000000       0.000000
# 26    16.066667   0.333333    0.000000       0.000000
# 27    15.800000   0.333333    0.000000       0.000000
# 28    16.833333   0.333333    0.333333       0.333333
# 29    16.733333   0.333333    0.333333       0.333333
# 30    17.900000   0.666667    0.333333       0.333333
# 31    17.400000   0.333333    0.333333       0.333333
# 32    16.033333   0.666667    0.333333       0.333333
# 33    16.266667   1.000000    0.333333       0.333333
# 34    16.033333   1.000000    0.000000       0.000000
# 35    17.400000   1.000000    0.000000       0.000000
# 36    16.233333   0.333333    0.000000       0.000000
# 37    16.333333   0.333333    0.000000       0.000000
#
# [35 rows x 39 columns]

# %%
matches.index = range(matches.shape[0]) # assign proper indices for matchweek

# %%
# this function does the predictions pretty similar to how they were made above, this time with the rolling averages included
def make_predictions(data, predictors):
    train = data[data["Date"] < '2024-01-01'] # training our data with first half of the season
    test = data[data["Date"] > '2024-01-01'] # testing on the last half of the season
    rf.fit(train[predictors], train["target"]) # train random forest model with predictors (defined above) to try to predict the target (win or loss/draw)
    preds = rf.predict(test[predictors]) # generate predictions
    combined = pd.DataFrame(dict(actual=test["target"], prediction=preds)) # creating a new dataframe with the actual results and predictions so we can compare
    precision= precision_score(test["target"], preds) # check precision
    return combined, precision

# %%
combined, precision = make_predictions(matches, predictors + new_cols)

# %%
precision
# Out:
# 0.6363636363636364

# %%
combined
# Out:
#     actual  prediction
# 17       1           0
# 18       1           0
# 19       0           0
# 20       1           1
# 21       1           0
# 22       1           1
# 23       1           1
# 24       0           1
# 25       1           1
# 26       1           1
# 27       0           1
# 28       0           1
# 29       1           1
# 30       0           0
# 31       0           1
# 32       1           1
# 33       0           0
# 34       1           0

# %%
combined = combined.merge(matches[["Date", "Opponent", "Result"]], left_index=True, right_index=True) # adding data to our combined dataframe to get more information

# %%
combined
# Out:
#     actual  prediction       Date         Opponent Result
# 17       1           0 2024-01-21      Bournemouth      W
# 18       1           0 2024-01-31          Chelsea      W
# 19       0           0 2024-02-04          Arsenal      L
# 20       1           1 2024-02-10          Burnley      W
# 21       1           0 2024-02-17        Brentford      W
# 22       1           1 2024-02-21       Luton Town      W
# 23       1           1 2024-03-02  Nott'ham Forest      W
# 24       0           1 2024-03-10  Manchester City      D
# 25       1           1 2024-03-31         Brighton      W
# 26       1           1 2024-04-04    Sheffield Utd      W
# 27       0           1 2024-04-07   Manchester Utd      D
# 28       0           1 2024-04-14   Crystal Palace      L
# 29       1           1 2024-04-21           Fulham      W
# 30       0           0 2024-04-24          Everton      L
# 31       0           1 2024-04-27         West Ham      D
# 32       1           1 2024-05-05        Tottenham      W
# 33       0           0 2024-05-13      Aston Villa      D
# 34       1           0 2024-05-19           Wolves      W

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pd.crosstab(index=combined["actual"], columns=combined["prediction"])
#
# NameError: name 'pd' is not defined
